# %%
from jobs import coins

symbol = 'GALAUSDT'

flow = coins.Coins(symbol, time='20', test=False).build_flow()
flow.run()
# Out:
# [2021-11-20 12:07:00+0100] INFO - prefect.FlowRunner | Beginning Flow run for 'Coins'
# [2021-11-20 12:07:00+0100] INFO - prefect.TaskRunner | Task 'extract': Starting task run...
# ...
